# %% [markdown]
# <a href="https://colab.research.google.com/github/Kloe2710/MindX---Final-Project/blob/main/Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import pandas as pd
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4b0c9532-2940-4e3e-a0c9-11e55ee484fc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4b0c9532-2940-4e3e-a0c9-11e55ee484fc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("Sample - Superstore.csv", encoding="latin-1")
df.head(5)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
# Xoá cột Row ID
df = df.drop(columns=['Row ID'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9994 non-null   object
#  1   Order Date     9994 non-null   object
#  2   Ship Date      9994 non-null   object
#  3   Ship Mode      9994 non-null   object
#  4   Customer ID    9994 non-null   object
#  5   Customer Name  9994 non-null   object
#  6   Segment        9994 non-null   object
#  7   Country        9994 non-null   object
#  8   City           9994 non-null   object
#  9   State          9994 non-null   object
#  10  Postal Code    9994 non-null   int64
#  11  Region         9994 non-null   object
#  12  Product ID     9994 non-null   object
#  13  Category       9994 non-null   object
#  14  Sub-Category   9994 non-null   object
#  15  Product Name   9994 non-null   object
#  16  Sales          9994 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df[df.duplicated]
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 3406  US-2014-150119  4/23/2014  4/27/2014  Standard Class    LB-16795
#
#        Customer Name      Segment        Country      City State  Postal Code  \
# 3406  Laurel Beltran  Home Office  United States  Columbus  Ohio        43229
#
#      Region       Product ID   Category Sub-Category  \
# 3406   East  FUR-CH-10002965  Furniture       Chairs
#
#                                            Product Name    Sales  Quantity  \
# 3406  Global Leather Highback Executive Chair with P...  281.372         2
#
#       Discount   Profit
# 3406       0.3 -12.0588

# %%
df_non_dup = df.drop_duplicates()
df_non_dup.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9993.000000   9993.000000  9993.000000  9993.000000  9993.000000
# mean   55191.576403    229.852846     3.789753     0.156188    28.660971
# std    32065.074478    623.276074     2.225149     0.206457   234.271476
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.731000
# 50%    56560.000000     54.480000     3.000000     0.200000     8.671000
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
# !ls
# Out:
#  drive	 sample_data  'Sample - Superstore.csv'   superstore_processed.csv

# %%
df_non_dup.to_csv("superstore_processed.csv", index=False)

# %%
files.download("superstore_processed.csv")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig = plt.subplots(figsize=(30,10))
sns.boxplot(x = df['Category'],
            y = df['Sales'])
# Out:
# <Axes: xlabel='Category', ylabel='Sales'>

# %%
sns.histplot(data=df_non_dup, x="Sales", bins=200)
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %%
sns.histplot(data=df_non_dup, x="Profit", bins=100)
# Out:
# <Axes: xlabel='Profit', ylabel='Count'>

# %%
sns.histplot(data=df_non_dup, x="Discount", bins=10)
# Out:
# <Axes: xlabel='Discount', ylabel='Count'>
